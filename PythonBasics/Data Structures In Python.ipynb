# %% [markdown]
# # DATA STRUCTURES IN PYTHON

# %%
L=[1,3,4.9,"name",3]
T=(1,3,4.9,"name",3)
S={1,3,4.9,"name",3}
D={23:"twothree",'B':43,'C':"CCD"}
print("The type of L is:",type(L))
print("The type of T is:",type(T))
print("The type of S is:",type(S))
print("The type of D is:",type(D))
# Out:
# The type of L is: <class 'list'>
# The type of T is: <class 'tuple'>
# The type of S is: <class 'set'>
# The type of D is: <class 'dict'>

# %%
print(L[1])
print(T[1])
print(3 in S) #Would return a true or false
print(D[23])
print(D['B'])
S #no duplicates would be printed becausse no duplicates are allowed in S
# Out:
# 3
# 3
# True
# twothree
# 43
# {1, 3, 4.9, 'name'}

# %%
L
# Out:
# [1, 3, 4.9, 'name', 3]

# %%
L[1:3]
# Out:
# [3, 4.9]

# %%
L[::-1]
# Out:
# [3, 'name', 4.9, 3, 1]

# %%
T[:3] #till the 4th element
# Out:
# (1, 3, 4.9)

# %%
List=["Hello","everybody","let's","learn"]
Tup=("Hello","everybode","let's","learn")
Set={"Hello","everybode","let's","learn"}
Dict={1:"Hello",2:"everybody",3:"let's",4:"learn"}

List=List+["insertion"]
print(List)

# Or we can use .append function to add an elemnt at the end of any list
#List.append("insertion")
#print(List)


Tup2=("insertion",)#"insertion"==("insertion"); so add a comma just to show that it is a tuple
Tup3=()
Tup3=Tup+Tup2
print(Tup3)

Set.add("insertion")
print(Set)

Dict[5]="insertion"
print(Dict)

#Concatenation caanot happen for a dictionary
Dict2={6:"six",7:"seven"}
#Dict3=Dict+Dict2
#print(Dict3)

# but we can use update function and add a whole new dictionary into an already existing dictionary
print("\n")
Dict.update(Dict2)
print(Dict)
# Out:
# ['Hello', 'everybody', "let's", 'learn', 'insertion']
# ('Hello', 'everybode', "let's", 'learn', 'insertion')
# {'learn', 'insertion', 'Hello', 'everybode', "let's"}
# {1: 'Hello', 2: 'everybody', 3: "let's", 4: 'learn', 5: 'insertion'}
#
#
# {1: 'Hello', 2: 'everybody', 3: "let's", 4: 'learn', 5: 'insertion', 6: 'six', 7: 'seven'}

# %%
del List[4]

# %%
List
# Out:
# ['Hello', 'everybody', "let's", 'learn']

# %%
Set
# Out:
# {'Hello', 'everybode', 'insertion', 'learn', "let's"}

# %%
Set.remove('insertion')

# %%
Set
# Out:
# {'Hello', 'everybode', 'learn', "let's"}

# %%
del Dict[5]

# %%
Dict
# Out:
# {1: 'Hello', 2: 'everybody', 3: "let's", 4: 'learn'}

# %%
List2=List

# %%
List2
# Out:
# ['Hello', 'everybody', "let's", 'learn', 'insertion']

# %%
'''Now if I make changes in List2 then List would also be changed because both variables are pointing toward
Same memory'''
List2[3]="Gunjan"
List2
#This is called referencing
# Out:
# ['Hello', 'everybody', "let's", 'Gunjan', 'insertion']

# %%
List
# Out:
# ['Hello', 'everybody', "let's", 'Gunjan', 'insertion']

# %%
#If you don't want this to happen then call copy function
List3=List.copy()
print(List3)
# Out:
# ['Hello', 'everybody', "let's", 'Gunjan', 'insertion']

# %%
List3[2]=44
List3
# Out:
# ['Hello', 'everybody', 44, 'Gunjan', 'insertion']

# %%
List#Same concept for Sets and dictionaries
# Out:
# ['Hello', 'everybody', "let's", 'Gunjan', 'insertion']

# %%
List3[2:5]
List3
#this way List# is already a copy and both DONOT point to the same memory. 
#Hence if we make changes to List3 it wont efect List
#in Numpy it is not true
# Out:
# ['Hello', 'everybody', 44, 'Gunjan', 'insertion']

# %%
L1=["start","def","9.6","jdfjd","end"]
L2=L1[::-2]
L2
# Out:
# ['end', '9.6', 'start']

# %%
L2.pop()
# Out:
# 'start'

# %%
L2
# Out:
# ['end', '9.6']

# %%
L2.append("start")

# %%
L2
# Out:
# ['end', '9.6', 'start']

# %%
L2.insert?

# %%
L2.insert(0,"hello")

# %%
L2
# Out:
# ['hello', 'end', '9.6', 'start']

# %%
Set
# Out:
# {'Hello', 'everybode', 'insertion', 'learn', "let's"}

# %%
A = {1, 2, 3}
B = {2}

#C = A.difference(B)      # returns a new set: {1, 3}
A.difference_update(B)   # modifies A to: {1, 3}
print(A)
print(B)
print(C)
# Out:
# {1, 3}
# {2}
# {1, 3}

# %%
L
# Out:
# [1, 3, 4.9, 'name']

# %%
S
# Out:
# {1, 3, 4.9, 'name'}

# %%
T
# Out:
# (1, 3, 4.9, 'name', 3)

# %%
D
# Out:
# {23: 'twothree', 'B': 43, 'C': 'CCD'}

# %%
D2={'A':L,'B':S,'C':T,'D':D}

# %%
D2
# Out:
# {'A': [1, 3, 4.9, 'name'],
#  'B': {1, 3, 4.9, 'name'},
#  'C': (1, 3, 4.9, 'name', 3),
#  'D': {23: 'twothree', 'B': 43, 'C': 'CCD'}}

# %%
D2['A'][2]
# Out:
# 4.9

# %%
K=D2['D']

# %%
for i in K:
    print(i,K[i])
# Out:
# 23 twothree
# B 43
# C CCD

# %%
L4=[L,T,D,"game",33]
type(L4[3])
# Out:
# str

# %%
L5=[x**2 for x in range(0,10)]#go from 0 to 10 do not include 10
L5
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
S3={x**2 for x in range(0,20,2)}# go from 0 to 20 do not include 20 with the step of 3 
S3
# Out:
# {0, 4, 16, 36, 64, 100, 144, 196, 256, 324}

# %%
'''You are a teacher and you have different student recordes containing id of a student and mark lists 
in each subject where each student has taken different number of subjects. All these records are in hard copy. 
You want to enter all the data in computer and want to compute average marks of each student 
display'''

def getDataFromUser():
    D={}
    while True:
        studentId = input("Enter student id: ")
        marksList = input("Enter the marks separated by comma: ")
        moreStudents = input("Enter 'no' to quit insertion:  ")
        if studentId in D:
            print(studentId, " is already inserted")
        else:
            D[studentId] = marksList.split(",")
        if moreStudents.lower() == "no":
            return D

# %%
data = getDataFromUser()
# Out:
# Enter student id: 1
# Enter the marks separated by comma: 90,98,97
# Enter 'no' to quit insertion:
# Enter student id: 2
# Enter the marks separated by comma: 99
# Enter 'no' to quit insertion:
# Enter student id: 3
# Enter the marks separated by comma: 100,98,99,94
# Enter 'no' to quit insertion:  no

# %%
data
# Out:
# {'1': ['90', '98', '97'], '2': ['99'], '3': ['100', '98', '99', '94']}

# %%
def getAvgMarks(D):
    avgMarks = {}
    for x in D:
        L= D[x]
        s=0
        for marks in L:
            s+=int(marks)
        avgMarks[x]=s/len(L)
    return avgMarks

# %%
avgM = getAvgMarks(data)

# %%
for x in avgM:
    print("Student: ",x,"got :",avgM[x]," of average marks")
# Out:
# Student:  1 got : 95.0  of average marks
# Student:  2 got : 99.0  of average marks
# Student:  3 got : 97.75  of average marks

# %%
#take the given string make it "Life is too short dont loose any time" 
mystring="life si oot, short dont loose, yna time   "
mystring = mystring.capitalize()
mystring = mystring.strip()
mystring = mystring.replace(","," ")
myList = mystring.split()
myList[1]=myList[1][::-1]
myList[2]=myList[2][::-1]
myList[6]=myList[6][::-1]

myList
# Out:
# ['Life', 'is', 'too', 'short', 'dont', 'loose', 'any', 'time']
