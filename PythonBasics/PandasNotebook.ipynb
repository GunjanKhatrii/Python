# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
a=pd.Series([2,3,4,5],index=["a","b","c","d"])#S capital for series

# %%
type(a.values)
# Out:
# numpy.ndarray

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
a['a']
# Out:
# 2

# %%
a['a':'d']#if you slice using explicit indices
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64

# %%
#second way to create series is create a dict and then make series of it like:
dict={1:33,2:56,3:78}
a=pd.Series(dict)

# %%
a
# Out:
# 1    33
# 2    56
# 3    78
# dtype: int64

# %%
grades_dict={"A":4,"B":3.5,"C":3,"D":2.5}
grades=pd.Series(grades_dict)

# %%
grades
# Out:
# A    4.0
# B    3.5
# C    3.0
# D    2.5
# dtype: float64

# %%
marks_dict={"A":85,"B":75,"C":65,"D":55}
marks=pd.Series(marks_dict)
marks
# Out:
# A    85
# B    75
# C    65
# D    55
# dtype: int64

# %%
marks[0:2]#access data using explicit or implicit both
# Out:
# A    85
# B    75
# dtype: int64

# %%
D=pd.DataFrame({'Marks':marks,'Grades':grades})

# %%
D
# Out:
#    Marks  Grades
# A     85     4.0
# B     75     3.5
# C     65     3.0
# D     55     2.5

# %%
D.T
# Out:
#            A     B     C     D
# Marks   85.0  75.0  65.0  55.0
# Grades   4.0   3.5   3.0   2.5

# %%
D.values
# Out:
# array([[85. ,  4. ],
#        [75. ,  3.5],
#        [65. ,  3. ],
#        [55. ,  2.5]])

# %%
D.values[2,0]
# Out:
# 65.0

# %%
D.columns
# Out:
# Index(['Marks', 'Grades'], dtype='object')

# %%
import numpy 
D['Scaled Marks']=numpy.round(90*(D['Marks']/100))

# %%
D
# Out:
#    Marks  Grades  Scaled Marks
# A     85     4.0          76.0
# B     75     3.5          68.0
# C     65     3.0          58.0
# D     55     2.5          50.0

# %%
E=D[D['Marks']>70]

# %%
E
# Out:
#    Marks  Grades  Scaled Marks
# A     85     4.0          76.0
# B     75     3.5          68.0

# %%
names_dict={1:'Gunjan',2:'Naman',3:'Sanjay',4:'Sonia',5:'Pratik'}
names=pd.Series(names_dict)

# %%
vaccined_dict={1:'F',2:'T',3:'T',4:'T',5:'T'}
vaccined=pd.Series(vaccined_dict)

# %%
DF=pd.DataFrame({'Names':names,'Vaccined':vaccined})
DF
# Out:
#     Names Vaccined
# 1  Gunjan        F
# 2   Naman        T
# 3  Sanjay        T
# 4   Sonia        T
# 5  Pratik        T

# %%
M=DF[DF['Vaccined']=='T']

# %%
M
# Out:
#     Names Vaccined
# 2   Naman        T
# 3  Sanjay        T
# 4   Sonia        T
# 5  Pratik        T

# %%
A=pd.DataFrame([{'a':1,'b':3},{'b':-3,'c':4}])

# %%
A
# Out:
#      a  b    c
# 0  1.0  3  NaN
# 1  NaN -3  4.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  1.0  3  0.0
# 1  0.0 -3  4.0

# %%
A.dropna()#causes data loss (drops all the rows with NaN)
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []
