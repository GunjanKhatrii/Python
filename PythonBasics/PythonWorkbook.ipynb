# %% [markdown]
# ## Control flow in python(simple programs to understand Syntax)

# %%
a=int(input("Enter any number: "))
if a>10:
    print(">10")
    print("Inside the top if")
    if a>20:
        print(">20")
        print("Inside the nested if")
    else:
        print("<20")
        print("Inside the else part of nested if")
print("Outside all ifs")
# Out:
# Enter any number: 34
# >10
# Inside the top if
# >20
# Inside the nested if
# Outside all ifs

# %%
a = int(input("Enter an integer between 0-100: "))
if a>0 and a<=100:
    
    if a % 2 ==0:
        print("the number is even")
    else:
        print("The number is odd")
else:
    print("The number is out of range")
# Out:
# Enter an integer between 0-100: 600
# The number is out of range

# %%
# Single line comment 

"""
User will enter a float number let say 238.915 . Your task is
to find out the integer portion before the point 
(in this case 238)and then check if that integer portion 
is even number or not.
"""

x=float(input("Enter a real number: "))
y=round(x)
if x>0:
    if y>x:
        intportion = y-1
    else:
        intportion = y
else:
    if y<x:
        intportion = y+1
    else:
        intportion = y
        
print(intportion)
if intportion % 2 == 0:
    print(intportion, "is even")
else:
    print("Integer portion is odd")
# Out:
# Enter a real number: -9.92
# -9
# Integer portion is odd

# %% [markdown]
# # loops

# %%
n=int(input("Enter the number of iterations you want: "))
i=1
while(i<n):
    if i%2 == 0:
        print(i)
    else:
        pass
    i+=1
print("done")
# Out:
# Enter the number of iterations you want: 6
# 2
# 4
# done

# %% [markdown]
# Break statement asks to exit the loop immediately and brings you outside the body of the loop.
# Continue statement brings the next iteration loaded regardless of the body of the loop.

# %%
n=int(input("Enter the number of iterations you want: "))
i=1
while True:
    if i%9 == 0:
        print("Inside if")
        break
    else:
        print("Inside else")
        i = i+1
print("Done")
# Out:
# Enter the number of iterations you want: 3
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside else
# Inside if
# Done

# %%
i=1
while True:
    if i%9 !=0:
        print("Inside if")
        i +=1
        continue
    print("Here i is divisible by 9")
    break
    
print("Done ho gaya")
# Out:
# Inside if
# Inside if
# Inside if
# Inside if
# Inside if
# Inside if
# Inside if
# Inside if
# Here i is divisible by 9
# Done ho gaya

# %%
L=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday',
   'Sunday','Blue','Green','Yellow','Invalid','Grey']
D=[]
C=[]
i=0
word=L[i]
while True:
    if word=='Invalid':
        break
        
    if word=='Monday' or 'Tuesday' or 'Wednesday' or 'Thursday' or 'Friday' or 'Saturday' or 'Sunday':
        D.append(word)
        i+=1
        continue
    
    
    C.append(word)
    i+=1
        
print(D)
print(C)
print("Lists updated")

# %%
L=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday',
   'Sunday','Blue','Green','Yellow','Invalid','Grey']
D=[]
C=[]
i=0
while True:
    if L[i] == "Invalid":
        break
    if i<7:
        D.append(L[i])
        i+=1
        continue
    C.append(L[i])
    i+=1
    
print(D)
print(C)
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
# ['Blue', 'Green', 'Yellow']

# %%
L=[]
for i in range(0,10,2): #range(start,stop-1,jump)
    print(i)
    L.append(i**2)
print(L)
# Out:
# 0
# 2
# 4
# 6
# 8
# [0, 4, 16, 36, 64]

# %%
''' Fibonacci series fn=f(n-1)+f(n-2)< By addition of previous 2 elements the next element is calculated'''
L=[]
n=int(input("Enter the number of enteries you want: "))
L.append(0)
L.append(1)
for i in range(2,n+1):
    L.append(L[i-1]+L[i-2])
print(L)
# Out:
# Enter the number of enteries you want: 5
# [0, 1, 1, 2, 3, 5]

# %%
#else in for loop
#When for completes its iterations then else part is executed
S={"apple",4.9,"cherry"}
i=1
for x in S:
    print(x)
else:
    print("Loop terminated")
print("out of the loop")
# Out:
# apple
# 4.9
# cherry
# Loop terminated
# out of the loop

# %%
''' In what case would else be not executed?-- if we use any break statement in the loop'''

S={'apple',4.9,"cherry"}
i=1
for x in S:
    print(x)
    i+=1
    if i==3:
        break
    else:
        pass
else:
    print("Loop terminated")
print("Out of loop")
# Out:
# apple
# 4.9
# Out of loop

# %%
#for loop is very helpfull to iterate over a dictionary
D={"apple":44,"cherry":"game"}
for x in D:
    print(x,D[x])
# Out:
# apple 44
# cherry game

# %%
'''Given a list of numbers i.e[1,2,4,-5,7,9,3,2], make 
another list that contains all the items in sorted order from min
to max .'''
L=[1,2,4,-5,7,9,3,2]
for j in range(len(L)):
    m=L[j]
    idx=j
    c=j
    for i in range(j,len(L)):
        if L[i]<m:
            m=L[i]
            idx=c
        c+=1
    tmp = L[j]
    L[j] = m
    L[idx] = tmp
print(L)
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %%
L=[1,2,4,-5,7,9,3,2]
m=L[0]
idx=0
c=0
for i in L:
    if i<m:
        m=i
        idx=c
    c+=1
tmp=L[0]
L[0]=m
L[idx]=tmp
print(L)
# Out:
# [-5, 2, 4, 1, 7, 9, 3, 2]

# %% [markdown]
# # functions

# %%
def printsuccess():
    '''This string does nothing'''
    print("The task was successfully executed")
    print("The function works as well,yayyy")

# %%
printsuccess()
# Out:
# The task was successfully executed
# The function works as well,yayyy

# %%
printsuccess??

# %%
def printmsg(msg):
    """The function prints the message supplied by the user or 
    prints the message is not in the form of the string"""
    if isinstance(msg,str):
        print(msg)
    else:
        print("Your message is not a string")
        print("Here is what you have provided",msg)
        print("The type of your input is:",type(msg))
printmsg(998)
# Out:
# Your message is not a string
# Here is what you have provided 998
# The type of your input is: <class 'int'>

# %%
def mypow(a,b):
    """This function computes just like builtin poaw function"""
    c=a**b
    print(c)
mypow(3,4)
# Out:
# 81

# %%
def checkargs(a,b,c):
    if isinstance(a,(int,float)) and isinstance(b,(int,float)) and isinstance(c,(int,float)):
        print((a+b+c)**2)
    else:
        print("Error : the input arguments are not of the expected types")
checkargs(2,3,4)
# Out:
# 81

# %%
checkargs(2.3,4,6)
# Out:
# 151.29000000000002

# %%
checkargs(3,4,"g")
# Out:
# Error : the input arguments are not of the expected types

# %%
ckeckargs(2,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 ckeckargs(2,3)
#
# NameError: name 'ckeckargs' is not defined

# %%
from math import pi
def areaofcircle(rad):
    if isinstance(rad,(int,float)):
        area= pi * rad**2
        print("Area of the circle is: "+ str(area))#type casting and string concatenation
    else:
        print("Error: You entered a wrong input.")
areaofcircle(3)
areaofcircle(8.9)
areaofcircle('hello')
# Out:
# Area of the circle is: 28.274333882308138
# Area of the circle is: 248.84555409084754
# Error: You entered a wrong input.

# %%
#default arguments
def f(a,b,c):
    print("A is :",a)
    print("B is :",b)
    print("C is :",c)

# %%
f(2,3,"Game")
# Out:
# A is : 2
# B is : 3
# C is : Game

# %%
f(c="game",a=2,b=3)
# Out:
# A is : 2
# B is : 3
# C is : game

# %%
#scope of a variable
def myadd(a,b):
    sumval = a+b
    return sumval

# %%
d = myadd(2,3)
print(d)
# Out:
# 5

# %%
variableoutsidethefunction=3
def g():
    variableoutsidethefunction=7
    #print(variableoutsidethefunction)
g()
# Out:
# 7

# %%
print(g())
type(g())
# Out:
# None
# NoneType

# %%
print(variableoutsidethefunction)
# Out:
# 3

# %%
#return works like a break statement in a loop 
#as soon as it occurs it exits the function
def h():
    print("A")
    a=3
    b=5
    c=a+b
    print("something")
    return c
    print("B")
    print("C")

# %%
h()
# Out:
# A
# something
# 8

# %%
#return statement can return multiple values
def r():
    a = 5
    b = 7
    c = "something"
    return a,b,c

# %%
x,y,z = r()
print(x,y,z)
# Out:
# 5 7 something

# %%
#variable number of arguments
def add(*args):
    sum = 0
    for i in range(len(args)):
         sum+=args[i]#sum=sum+args[i]
    return sum

# %%
add(3,4,5,6,4.6,55)
# Out:
# 77.6

# %%
def oddeven(*args):
    odd = 0
    even = 0
    for i in range(len(args)):
        if args[i]%2==0:
            even+=1
        else:
            odd+=1
    print("Number of even numbers are: ",even)
    print("Number of odd numbers are: ",odd)

# %%
oddeven(2,3,4,5)
# Out:
# Number of even numbers are:  2
# Number of odd numbers are:  2

# %%
#variable number of arguments as a dictionary 

def printallvariablenamesandvalues(**args):
    
    for x in args:
        print("The variable is: ",x," And its value is: ",args[x])
        
printallvariablenamesandvalues(a=3,b="b",c=78.9)
# Out:
# The variable is:  a  And its value is:  3
# The variable is:  b  And its value is:  b
# The variable is:  c  And its value is:  78.9

# %%
def giveavg(**args):
    sum=0
    c=0
    for x in args:
        print("The subject is:",x," And marks in this subject are: ",args[x])
        sum+=args[x]
        
    print("The average of marks are:", sum/len(args))
giveavg(Maths = 79,English = 88,Science=65.2,Computer=71.2,Accounting=81)
# Out:
# The subject is: Maths  And marks in this subject are:  79
# The subject is: English  And marks in this subject are:  88
# The subject is: Science  And marks in this subject are:  65.2
# The subject is: Computer  And marks in this subject are:  71.2
# The subject is: Accounting  And marks in this subject are:  81
# The average of marks are: 76.88

# %%
import sys
sys.path.append('/Users/gunjankhatri/Downloads')

# %%
import My_Universal_functions as myfs

# %%
c = myfs.addallnumerics(2,3,4,5)
print(c)
# Out:
# 14

# %%
from My_Universal_functions import addallnumerics

# %%
d = addallnumerics(2,3,4,6,5)
print(d)
# Out:
# 20

# %%
myfs.myName
# Out:
# 'Python Course'

# %%
'''Given a list of numbers i.e[1,2,4,-5,7,9,3,2], make 
another list that contains all the items in sorted order from min
to max .'''
# Out:
# 'Given a list of numbers i.e[1,2,4,-5,7,9,3,2], make \nanother list that contains all the items in sorted order from min\nto max .'

# %%
def findmin(L,startindex):
    m=L[startindex]
    idx=startindex
    for i in range(startindex,len(L)):
        x = L[i]
        if x<m:
            m = x
            idx = i
        else:
            pass
    return  m,idx

# %%
a,b= findmin([2,3,5,4,9],0)

# %%
print(a,b)
# Out:
# 2 0

# %%
def swapval(L,idx1,idx2):
    tmp = L[idx1]
    L[idx1] = L[idx2]
    L[idx2] = tmp
    return L

# %%
L = [2,3,5,7]
L2 = swapval(L,1,3)
print(L2)
# Out:
# [2, 7, 5, 3]

# %%
from My_Universal_functions import checkifnotnumeric
def sortlist(L):
    if not(checknumeric(L)):
        print(" Error: List does not contain numeric values ")
        return
    else:
        c=0
        for x in L:
            m,idx = findmin(L,c)
            L = swapval(L,c,idx)
            c+=1
    return L

# %%
def checknumeric(L):
    for x in L:
        if not(isinstance(x,(int,float))):
            return False
        return True

# %%
L2 = sortlist([2,3,-8,5,6])
print(L2)
# Out:
# [-8, 2, 3, 5, 6]

# %% [markdown]
# # strings

# %%
s="Python is a good language"
t="It's good for data science"

# %%
type(s)
# Out:
# str

# %%
print(s)
# Out:
# Python is a good language

# %%
print("Hello",12,"hello2",'who are you',5.9)
# Out:
# Hello 12 hello2 who are you 5.9

# %%
v=s+". "+t

# %%
print(v)
# Out:
# Python is a good language. It's good for data science

# %%
price = 12
s="The price of this book"
v = s + 'is: ' + str(price)
print(v)
print(s," is:",price)
# Out:
# The price of this bookis: 12
# The price of this book  is: 12

# %%
a="""This is line 1
this is line 2
this is line 3"""
print(a)
# Out:
# This is line 1
# this is line 2
# this is line 3

# %%
s="How are you and who are you"
print(s[5])
type(s[5])
# Out:
# r
# str

# %%
s[:9]
# Out:
# 'How are y'

# %%
s[-1]
# Out:
# 'u'

# %%
s[-3]
# Out:
# 'y'

# %%
s[-12:-3]
# Out:
# ' who are '

# %%
s[8]="e" #This cannot happen and will show an error.
#Hence strings in python are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s[8]="e"
#
# TypeError: 'str' object does not support item assignment

# %%
s[0:12:2] #s[start:end:step]
# Out:
# 'Hwaeyu'

# %%
s[::-1]
# Out:
# 'uoy era ohw dna uoy era woH'

# %%
mystring="Hello guys whats up?"
a=mystring[::-1]
print(a)
# Out:
# ?pu stahw syug olleH

# %%
print(a[10:])
# Out:
# syug olleH

# %%
b=mystring[11:16]
print(b[::-1])
# Out:
# stahw

# %%
'''String methods
Those functions that are associated with datastructures and are called using a dot are sometimmes called methods.'''
# Out:
# 'String methods\nThose functions that are associated with datastructures and are called using a dot are sometimmes called methods.'

# %%
a="    ABC Def hgq  asdnjhi   "
b=a.strip()
print(b)
# Out:
# ABC Def hgq  asdnjhi

# %%
a="ABD efk GHF Huf"
b=a.lower()
print(b)
# Out:
# abd efk ghf huf

# %%
a="Hubffj ;; jghug HGIIK "
b=a.upper()
print(b)
# Out:
# HUBFFJ ;; JGHUG HGIIK

# %%
d=a.replace(";","*")
print(d)
# Out:
# Hubffj ** jghug HGIIK

# %%
a="abd:gehf:tjyu:kjuh:klkhij"
L=a.split(":")
print(L)
# Out:
# ['abd', 'gehf', 'tjyu', 'kjuh', 'klkhij']

# %%
L[2]
# Out:
# 'tjyu'

# %%
a="life si oot,short dont loose,yna time  "
b=a.strip()
#print(b)
c=b.replace(","," ")
print(c)
# Out:
# life si oot short dont loose yna time
